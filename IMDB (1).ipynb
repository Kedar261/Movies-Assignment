# %%
import pandas as pd
df = pd.read_csv('IMDB_dataset.csv')
df
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
df.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
df.shape
# Out:
# (100, 62)

# %%
##Highest Budget Movie

# %%
df[df.budget==df.budget.max()]['Title']
# Out:
# 7    Tangled
# Name: Title, dtype: object

# %%
df.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country'],
#       dtype='object')

# %% [markdown]
# # Top 5 IMDB rating

# %%
df.IMDb_rating.nlargest()
# Out:
# 27    8.8
# 26    8.6
# 95    8.5
# 8     8.4
# 35    8.4
# Name: IMDb_rating, dtype: float64

# %% [markdown]
# # Title of Movies in 2016

# %%
df[df.title_year==2016].Title
# Out:
# 0                     La La Land
# 1                       Zootopia
# 2                           Lion
# 3                        Arrival
# 4          Manchester by the Sea
# 5             Hell or High Water
# 6                 Doctor Strange
# 9     Captain America: Civil War
# 47                      Deadpool
# Name: Title, dtype: object

# %% [markdown]
# # make a list of previous question

# %%
df1 = df[df.title_year==2016].Title
l = list(df1)
l
t = tuple(df1)
t
# Out:
# ('La La Land',
#  'Zootopia',
#  'Lion',
#  'Arrival',
#  'Manchester by the Sea',
#  'Hell or High Water',
#  'Doctor Strange',
#  'Captain America: Civil War',
#  'Deadpool')

# %% [markdown]
# # rating for perticular moving e.g skyfall

# %%
df[df.Title == "Skyfall"].IMDb_rating
# Out:
# 13    7.8
# Name: IMDb_rating, dtype: float64

# %% [markdown]
# # no of movies by  Tom Cruise

# %%
len(df[df.actor_1_name == "Tom Cruise"])+len(df[df.actor_2_name == "Tom Cruise"])+len(df[df.actor_3_name == "Tom Cruise"])
# Out:
# 1

# %%
len(df[(df.actor_1_name =="Tom Cruise") | (df.actor_2_name =="Tom Cruise")  | (df.actor_3_name =="Tom Cruise")])
# Out:
# 1

# %% [markdown]
# # name of the movie by Tom cruz

# %%
df[df.actor_1_name == "Tom Cruise"].Title
# Out:
# 17    Edge of Tomorrow
# Name: Title, dtype: object

# %% [markdown]
# # Movie famous on Facebook on basis of all actors like

# %%
df1  = df.actor_1_name.fillna(0)
df1
# Out:
# 0                 Ryan Gosling
# 1             Ginnifer Goodwin
# 2                    Dev Patel
# 3                    Amy Adams
# 4                Casey Affleck
#                 ...
# 95                J.K. Simmons
# 96    Seamus Davey-Fitzpatrick
# 97                 Doug Walker
# 98                Rupert Grint
# 99              Katrina Bowden
# Name: actor_1_name, Length: 100, dtype: object

# %%
fb = df.actor_1_facebook_likes + df.actor_2_facebook_likes + df.actor_3_facebook_likes
fb
# Out:
# 0          NaN
# 1      57800.0
# 2     138800.0
# 3          NaN
# 4      74818.0
#         ...
# 95     25505.0
# 96       251.0
# 97       143.0
# 98     13000.0
# 99      2167.0
# Length: 100, dtype: float64

# %%
dfb = df[['actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']].fillna(0)
sumfb = dfb.actor_1_facebook_likes +dfb.actor_2_facebook_likes + dfb.actor_3_facebook_likes
sumfb
# Out:
# 0      33000.0
# 1      57800.0
# 2     138800.0
# 3      40300.0
# 4      74818.0
#         ...
# 95     25505.0
# 96       251.0
# 97       143.0
# 98     13000.0
# 99      2167.0
# Length: 100, dtype: float64

# %%
dfb.max()
# Out:
# actor_1_facebook_likes    35000.0
# actor_2_facebook_likes    96000.0
# actor_3_facebook_likes    46000.0
# dtype: float64

# %%
#fetch movie records from year 2012 to 2016

# %%
df.title_year.value_counts().tail()
# Out:
# 2013    17
# 2012    13
# 2015    12
# 2011    11
# 2016     9
# Name: title_year, dtype: int64

# %%
df[(df.title_year>=2012) & (df.title_year<=2016)]
# Out:
#                                          Title  title_year     budget  \
# 0                                   La La Land        2016   30000000
# 1                                     Zootopia        2016  150000000
# 2                                         Lion        2016   12000000
# 3                                      Arrival        2016   47000000
# 4                        Manchester by the Sea        2016    9000000
# ..                                         ...         ...        ...
# 93                          Dallas Buyers Club        2013    5000000
# 94                                     Boyhood        2014    4000000
# 95                                    Whiplash        2014    3300000
# 96                             Before Midnight        2013    3000000
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
#
#         Gross              actor_1_name        actor_2_name  \
# 0   151101803              Ryan Gosling          Emma Stone
# ...

# %%
#fetch movie whose name start with 'T'

# %%
df[df.Title.str.startswith('T')].Title
# Out:
# 7                                 Tangled
# 8                   The Dark Knight Rises
# 10    The Hobbit: The Desolation of Smaug
# 11                           The Avengers
# 12                            Toy Story 3
# 16      The Hobbit: An Unexpected Journey
# 31                           The Revenant
# 32        The Hunger Games: Catching Fire
# 33                            The Martian
# 36                The Wolf of Wall Street
# 38        The Girl with the Dragon Tattoo
# 39                      The Little Prince
# 45                         The Lego Movie
# 53                     The Social Network
# 55                              True Grit
# 57                               The Town
# 62                          The Big Short
# 63                               The Help
# 64                            The Fighter
# 65               The Grand Budapest Hotel
# 71                         The Book Thief
# 76                      The King's Speech
# ...
